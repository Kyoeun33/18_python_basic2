# %%
# 변수의 사용범위 알아보기

x= 10

def foo():
    print(x)

foo()
print(x)
# Out:
# 10
# 10

# %%
def foo ():
    y = 10
    print(y)

foo()
print(y)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       2     y = 10
#       3     print(y)
#       4
#       5 foo()
# ----> 6 print(y)
#
# NameError: name 'y' is not defined

# %%
# 함수 안에서 전역 변수 변경하기

x = 10
def foo():
    x =20
    print(x)

foo()
print(x)
# Out:
# 20
# 10

# %%
# global 전역 변수

x =10
def foo ():
    global x
    x = 20
    print(x)

foo()
print(x)
# Out:
# 20
# 20

# %%
def foo():
    global a 
    a = 20
    print(a)

foo()
print(a)
# Out:
# 20
# 20

# %%
# 함수 안에서 함수 만들기
def print_hello():
    hello = "hello, world"
    def print_message():
        print(hello)
    print_message()

print_hello()

# %%
# 지역 변수 변경하기

def A():
    x=10
    def B ():
        x = 20
    B()
    print(x)

A()
# Out:
# 10

# %%
# nonlocal 지역변수

def A():
    x =10
    def B ():
        nonlocal x
        x=20
    B()
    print(x)

A()
# Out:
# 20

# %%
# nonlocal이 변수를 찾는 순서

def A():
    x =10
    y =100
    def B():
        x =20
        def C ():
            nonlocal x
            nonlocal y
            x= x+30
            y=y+300
            print(x)
            print(y)
        C()
    B()
A()
# Out:
# 50
# 400

# %%
# global로 전역 변수 사용하기

x = 1

def A():
    x =10
    def B () :
        x = 20
        def C():
            global x
            x = x+30
            print(x)

        C()
    B()
A()
# Out:
# 31

# %%
# 클로저 사용하기

def calc():
    a = 3
    b = 5
    def mul_add(x):
        return a * x +b
    return mul_add

c = calc()

print(c(1),c(2),c(3),c(4),c(5)) # c(x)
# Out:
# 8 11 14 17 20

# %%
# lambda 로 클로저 만들기

def calc():
    a = 3
    b = 5
    return lambda x : a * x + b

c = calc()
print(c(1))
# Out:
# 8

# %%
# 클로저의 지역 변수 변경하기
def cala():
    a=3
    b=5
    total =0
    def mul_add (x):
        nonlocal total
        total = total + a * x +b
        print(total)
    return mul_add

c = calc() ## 다르게 하니까 아예 오류
c(1)
# Out:
# 8

# %%
# Out:
# False
