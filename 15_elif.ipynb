# %%
# elif 사용하기
if 조건식 :
    수행할 코드1
elif 조건식2 :
    수행할코드2
else :
    수행할코드3

x = 20

if x == 10 :
    print("10입니다.")
elif x == 20 :
    print("20입니다.")

# %%
x = 15

if x == 10 :
    print("10입니다.")
elif x == 20 :
    print("20입니다.")

# %%
x = 15

if x == 10 :
    print("10입니다.")
elif x == 20 :
    print("20입니다.")
else:
    print("10도 20도 아닙니다.")
# Out:
# 10도 20도 아닙니다.

# %%
x = 15

if x == 10 :
    print("10입니다.")
else:
    print("10도 20도 아닙니다.")
elif x == 20 :
    print("20입니다.")
# Out:
#   Cell In[6], line 7
#     elif x == 20 :
#     ^
# SyntaxError: 'elif' block follows an 'else' block

# %%
# 음료수 자판기 만들기

button = int(input())
if button ==1 :
    print("콜라")
elif button ==2:
    print("사이다")
elif button == 3:
    print ("환타")
else :
    print ("제공하지 않는 메뉴")
# Out:
# 환타

# %%
## 예제

x = int(input())

if 11<x<20 :
    print("11~20")
elif 21<x<30 :
    print("21~30")
else : 
    print ("해당되지 않음")
# Out:
# 해당되지 않음

# %%
age = int(input())
card = 9000

if 7 <= age <=12 :
    print(card - 650)
elif 13 <= age <=18 :
    print(card - 1050)
else :
    print(card - 1250)
# Out:
# 8350

# %%
age = int(input())
card = 9000

if 7 < age <12 :
    print(card - 650)
elif 13 < age <18 :
    print(card - 1050)
elif 19 < age:
    print(card - 1250)
else :
    print("retry")
# Out:
# retry
