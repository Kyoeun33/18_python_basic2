# %%
# else 사용하기
# if 조건식 : 
#     수행할 코드1
# else :
#     수행할 코드2


x = 5
if x == 10:
    print("10입니다.")
else :
    print("10이 아닙니다.")
# Out:
# 10이 아닙니다.

# %%
# else와 들여쓰기

x = 5
if x == 10:
    print("10입니다.")
else :
    pass
print("10이 아닙니다.")
# Out:
# 10이 아닙니다.

# %%
x = 5
if x == 10:
    print("10입니다.")
else :
    print("X에 들어있는 숫자는")
    print("10이 아닙니다.")
# Out:
# X에 들어있는 숫자는
# 10이 아닙니다.

# %%
x = 10
if x == 10:
    print("10입니다.")
else :
    print("X에 들어있는 숫자는")

    
print("10이 아닙니다.")
# Out:
# 10입니다.
# 10이 아닙니다.

# %%
# if조건문의 동작 방식 알아보기

if True :
    print ( "참")
else : 
    print("거짓")

if False :
    print ("참")
else : 
    print("거짓")

if None : 
    print("참")
else :
    print("거짓")
# Out:
# 참
# 거짓
# 거짓

# %%
# 조건문에 숫자 지정하기

if 0: 
    print("참")
else :
    print ("거짓")

if 1 :
    print("참")
else :
    print("거짓")

if 0x1f :
    print("참")
else :
    print("거짓")

if 0b1000:
    print('참')
else :
    print(거짓)


if  15.5 : 
    print('참')
else :
    print("거짓")
# Out:
# 거짓
# 참
# 참
# 참
# 참

# %%
#if조건문에 문자열 지정하기

if " hello " : 
    print('true')
else : 
    print('false')

if '':
    print('true')
else :
    print('false')

if ' ':
    print('true')
else :
    print('false')
# Out:
# true
# false
# true

# %%
#조건식을  여러개 지정하기

x =10
y=20

if x == 10 and y == 20 :
    print('true')
else :
    print('false')
# Out:
# true

# %%
# 중첩 if조건문과 논리 연산자

if x > 0 :
    if x <20 :
        print('20보다 작은 양수 입니다.')
# Out:
# 20보다 작은 양수 입니다.

# %%
if x > 0 and x < 20 :
    print('20보다 작은 양수 입니다.')
# Out:
# 20보다 작은 양수 입니다.

# %%
if 0 < x < 20 :
    print("20볻 작은 양수입니다.")
# Out:
# 20볻 작은 양수입니다.

# %%
# 예제


written_test = 75
coding_test = True

if written_test >= 80 and coding_test==True :
    print("합격")
else :
    print("불합격")
# Out:
# 불합격

# %%
A,B,C,D=input().split()
A = int(A)
B = int(B)
C = int(C)
D = int(D)
ave = (A+B+C+D)/4

if 0 < A<= 100 and 0 < B<= 100 and 0 < C<= 100 and 0 < D <= 100 :
    pass
    if ave >= 80 :
        print("합격")
    else :
        print("불합격")
else :
    print("잘못된 점수")
# Out:
# 합격

# %%
A,B,C,D=map(int,input().split())
A,B,C,D
# Out:
# (1, 2, 3, 4)

# %%
국어, 영어, 수학, 과학 = list(map(int,input().split()))

if 0<= 국어 <= 100 and 0<= 영어 <= 100 and 0<= 수학 <= 100 and 0<= 과학 <= 100 :
    avg = (국어 +영어+수학+과학)/4
    if avg >= 80 :
        print ("합격")
    else :
        print("불합격")
else :
    print("잘못된 점수")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 국어, 영어, 수학, 과학 = list(map(int,input().split()))
#       2
#       3 if 0<= 국어 <= 100 and 0<= 영어 <= 100 and 0<= 수학 <= 100 and 0<= 과학 <= 100 :
#       4     avg = (국어 +영어+수학+과학)/4
#
# ValueError: not enough values to unpack (expected 4, got 0)

# %%
a,b,c,d =[1,2,3,4]
a+b

type(a)
# Out:
# int
