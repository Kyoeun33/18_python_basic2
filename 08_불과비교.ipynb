# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
#  비교연산자
3 > 1
# Out:
# 6

# %%
# 숫자가 같은 지 다른 지 비교
print(10 == 10)
print(10 != 10)
# Out:
# True
# False

# %%
print("python"=="python")
print ("python"=="Python")
# Out:
# True
# False

# %%
# 부등호 사용
print(10 >20)
print(10 <20)
print(10 >=20)
print(10 <=20)
# Out:
# False
# True
# False
# True

# %%
print(1 == 1.0)
# print(1 is 1.0) #요즘은 안쓰는 그건 거,,
print(id(1))
print(id(1.0))
# Out:
# True
# 140711696524408
# 2013975981936

# %%
# = , == , ===

print(1 is 1.0)
# Out:
# False
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_17180\1825513739.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(1 is 1.0)

# %%
# 논리 연산자 사용하기

print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
print(True and True and True)
print(False and True and True)
# Out:
# True
# False

# %%
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
not True
# Out:
# False

# %%
not True and False or not False

False and False or True

False or True
# Out:
# True

# %%
#논리연산자와 비교 연산자를 함께 사용하기

print(10 ==10 and 5 != 5)
print(10> 5 or 10 < 3)
print(not 10>5)
print(not 1 is 1.0)
# Out:
# False
# True
# False
# True
# <>:6: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:6: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_17180\2396030969.py:6: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(not 1 is 1.0)

# %%
print(False >5)
print(0>True)  # ???
# Out:
# False
# False

# %%
korean = 92
english = 47
math = 86
science = 81

print(korean < 50 and english < 50 and math <50 and science < 50)
# Out:
# False

# %%
kr,en,ma,sc=(map(int,input().split()))

print(kr>=90 and en >80 and ma > 85 and sc >= 80 )
# Out:
# False
