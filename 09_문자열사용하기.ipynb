# %%
#문자열 사용
hello = "hello world"

hello
# Out:
# 'hello world'

# %%
hello = '안녕'
hello
# Out:
# '안녕'

# %%
hello ='''hello, python'''
hello
# Out:
# 'hello, python'

# %%
python ="""python programming"""

python
# Out:
# 'python programming'

# %%
#여러줄로 된 문자열 사용하기

hello ='''hello world
안녕하세요
python입니다'''

print(hello)
# Out:
# hello world
# 안녕하세요
# python입니다

# %%
# 문자열 안에 작은 따옴표나 큰 따옴표 포함하기
s = "pyton isn's difficult"
s
# Out:
# "pyton isn's difficult"

# %%
'he said "python is easy'
# Out:
# 'he said "python is easy'

# %%
single_quote='''
"안녕하세여."'파이썬'입니다.
'''
print(single_quote)
# Out:
# "안녕하세여."'파이썬'입니다.

# %%
A = '''
python is a programing languages that lets you work quickly
and
integrate systems more effectively'''

print(A)
# Out:
# python is a programing languages that lets you work quickly
# and
# integrate systems more effecovely

# %%
A = '''
'python' is a "programin language" 
that lets you work quickly
and
integrate systmes more effectively'''

print(A)
# Out:
# 'python' is a "programin language"
# that lets you work quickly
# and
# integrate systmes more effectively
