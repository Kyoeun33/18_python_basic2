# %%
# #딕셔너리 만들기

# 딕셔너리 = {
#     키1 : 값1,
#     키2 : 값2,
# }

lux ={
    "health" : 490,
    "mana" : 334,
    "melee":550,
    "armor":18.72
    }

lux
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
#키 이름이 중복이 되면?


lux ={
    "health" : 490,
    "health" : 800,
    "mana" : 334,
    "melee":550,
    "armor":18.72
    }

lux["health"]
# Out:
# 800

# %%
lux
# Out:
# {'health': 800, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
# 딕셔너리의 키의 자료형
#키에는 리스트와 딕셔너리는 사용할 수 없음

x = {
    100: " hundred",
    False : 0,
    3.5 : [3.5,3.5] ,


}
x
# Out:
# {100: ' hundred', False: 0, 3.5: [3.5, 3.5]}

# %%
x={
    [10,20]:100
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x={
#       2     [10,20]:100
#       3 }
#
# TypeError: cannot use 'list' as a dict key (unhashable type: 'list')

# %%
#빈 딕셔너리 만들기

딕셔너리 =[]
딕셔너리 =dict()

# int() str() float() list() tuple() bool()

x = {}
y = dict()

print(x)
print(y)
print(type(x))
print(type(y))
# Out:
# {}
# {}
# <class 'dict'>
# <class 'dict'>

# %%
#dict로 딕셔너리 만들기

a= dict(
    health = 490,mana = 334, melee = 550, armor = 18.72
)

type(a)
# Out:
# dict

# %%
iter1 = ["health","mana","melee","armor"]
iter2 = [490, 334, 550, 18,72]

# list(zip(iter1,iter2))

dict(zip(iter1,iter2))
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18}

# %%
lux3 = dict(
    [("health",490),("mana",344),("melee",550),("armor",18.72)]
)

lux3
# Out:
# {'health': 490, 'mana': 344, 'melee': 550, 'armor': 18.72}

# %%
lux4  = dict (
    {'health': 490, 'mana': 344, 'melee': 550, 'armor': 18.72}
)

lux4
# Out:
# {'health': 490, 'mana': 344, 'melee': 550, 'armor': 18.72}

# %%
#딕셔너리의 키에 접근하도 값 할당하기
lux = {'health': 490, 'mana': 344, 'melee': 550, 'armor': 18.72}

lux["health"]
# Out:
# 490

# %%
lux[ "armor"]
# Out:
# 18.72

# %%
# 딕셔너리의 키에 값 할당하기
lux = {'health': 490, 'mana': 344, 'melee': 550, 'armor': 18.72}
lux["health"] = 2037
lux["mana"] = 1184

# %%
lux["mana_regen"]=3.28
lux
# Out:
# {'health': 2037,
#  'mana': 1184,
#  'melee': 550,
#  'armor': 18.72,
#  'mana_regen': 3.28}

# %%
lux["attack_speed"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 lux["attack_speed"]
#       2
#
# KeyError: 'attack_speed'

# %%
lux.get("attack_speed")

# %%
# 딕셔너리에 키가 있는 지 확인하기
lux = {'health': 490, 'mana': 344, 'melee': 550, 'armor': 18.72}
"health" in lux
# Out:
# True

# %%
#딕셔너리에 키 갯수 구하기
lux = {'health': 490, 'mana': 344, 'melee': 550, 'armor': 18.72}
len(lux)
# Out:
# 4

# %%
camille = {
    'health' : 275.6,
    'health_regon' : 1.7,
    'mana' : 338,
    'mana_regon' : 1.63,
    'melee' : 126,
    'attack_dmage':60,
    'attack_speed' : 0.625,
    'armor':26,
    'masic_resistance':32.1,
    'movement_speed':340,
}

print(camille["health"],camille["movement_speed"])
# Out:
# 275.6 340

# %%
a= input().split()
b= input().split()




c= dict(zip(a,b))

print(c)
print(type(b[0]))
print(type(b))
# Out:
# {'q': '1', 'w': '2', 'e': '3', 'r': '4'}
# <class 'str'>
# <class 'list'>

# %%
a= input().split()
b= [int(x) for x in input().split()]


c= dict(zip(a,b))

print(c)
# Out:
# {'q': 1, 'w': 2, 'e': 3, 'r': 4}

# %%
a= input().split()
b= tuple(int(x) for x in input().split())


c= dict(zip(a,b))

print(c)
# Out:
# {'q': 1, 'w': 2, 'e': 3, 'r': 4}
