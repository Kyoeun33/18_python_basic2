# %%
#세미콜론
print('hello world');
# Out:
# hello world

# %%
print("hello");print('1234')
# Out:
# hello
# 1234

# %%
# 한줄 주석
print( " hello world")
# Out:
#  hello world

# %%
#블록 주석

# print( " hello world")  

# print( " hello world")  

# print( " hello world")

# %%
# 들여쓰기
a=5
if a == 10:
    print ("10입니다")
    print("5")
if a == 10:
