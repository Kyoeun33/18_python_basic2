# %%
result = 0

def add(num):
    global result
    result += num
    return result

print(add(5))
print(add(10))
# Out:
# 5
# 15
# 15

# %%
result_2 = 0

def add_2(num):
    global result_2
    result_2 += num
    return result_2

print(add_2(3))
print(add_2(5))
# Out:
# 3
# 8

# %%
class Calculator():
    def __init__(self):
        self.result = 0

    def add(self, num):
        self.result += num
        return self.result

cal1 = Calculator()
print(cal1.add(5))
print(cal1.add(10))

cal2 = Calculator()
print(cal2.add(3))
print(cal2.add(78))
# Out:
# 5
# 15
# 3
# 81

# %%
# 클래스와 매서드 만들기

# class 클래스이름:
#     def 매서드(slef):
#         코드

class Person:
    def greeting(self):
        print("hello")

# %%
# 인스턴스 = 클래스()
# a = [1,2,3]
# a.append()
james = Person()
# 메서드 호출하기
james.greeting()
# Out:
# hello

# %%
# 파이썬에서 흔히 볼 수 있는 클래스

a = int(10)
a
# Out:
# 10

# %%
b =list(range(10))

# %%
c = dict(x = 10,y=20)

# %%
type(a)
# Out:
# int

# %%
# 속성 사용하기
# class 클래스 이름 :
#     def__init__(self):
#         self.속성 = 값

class Person:
    def __init__(self):
        self.hello="안녕하세요"
    def greeting(self):
        print(self.hello)


james = Person()
print(james.hello)
james.greeting()
# Out:
# 안녕하세요
# 안녕하세요

# %%
# 인스턴스를 만들 때 값 받기

# class 클래스 이름:
#     def __init__(self,매개변수1,매개 변수 2):
#         self.속성1 = 매개변수1
#         self.속성2 = 매개변수2

class Person:
    def __init__(self,name,age,address):
        self.hello='안녕하세요'
        self.name = name
        self.age = age
        self.address = address

    def greeting(self):
        print(f"{self.hello} 저는 {self.name}입니다.")

maria = Person("마리아",28,"서울시 서초구 반포동")

maria.greeting()
# Out:
# 안녕하세요 저는 마리아입니다.

# %%
# 예제

# 34.5

class Knight :
    def __init__(self,health, mana, armor):
        self.health = health
        self.mana = mana
        self.armor = armor
    def slash(self):
        print("베기")

#######################
x = Knight(health = 543.4 , mana = 210.3, armor = 38)
print(x.health, x.mana, x.armor)
x.slash()
# Out:
# 543.4 210.3 38
# 베기

# %%
#34.6

class Annie:
    def __init__(self,health,mana,ability_power):
            self.health = health
            self.mana = mana
            self.ability_power = ability_power

    def tibbers(self):
          print('티버: 피해량 ',ability_power*0.65+400)


health, mana, ability_power = map(float, input().split())

x = Annie(health = health, mana=mana,ability_power=ability_power)
x.tibbers()
# Out:
# 티버 피해량  819.25
