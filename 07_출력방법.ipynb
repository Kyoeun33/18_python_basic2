# %%
# 값을 여러개 출력하기
print(1,2,3)
print("hello","python")
# Out:
# 1 2 3
# hello python

# %%
# sep으로 값 사이에 문자 넣기
print(1,2,3)
print (1,2,3, sep= "," )
# Out:
# 1 2 3
# 1,2,3

# %%
print("hello","python")
print("hello","python", sep ="")
# Out:
# hello python
# hellopython

# %%
print(1920,1080, sep="x")
# Out:
# 1920x1080

# %%
# 줄바꿈 활용
print(1,2,3)
print(1,2,3, sep="\n")
# Out:
# 1 2 3
# 1
# 2
# 3

# %%
print("1\n2\n3")
# Out:
# 1
# 2
# 3

# %%
## end 사용하기
print(1)
print(2)
print(3)
# Out:
# 1
# 2
# 3

# %%
print(1,end="")
print(2,end="")
print(3,end=" ")
print(4,end="")
# Out:
# 123 4

# %%
print(1,end="   ")
print(2,end="   ")
print(3,end=" ")
print(4,end="    ")
# Out:
# 1   2   3 4

# %%
year = 2000
month = 10
day = 27
hour = 11
mintue = 43
second = 59

print(year,month,day, sep="/")
print(hour,mintue,second,sep=":")
# Out:
# 2000/10/27
# 11:43:59

# %%
year,month,days,hours,mintues,sec = map(int,(input("").split()))

print(year,month,days,sep="-",end="T")
print(hours,mintues,sec,sep=":")
# Out:
# 1-2-3T4:5:6
